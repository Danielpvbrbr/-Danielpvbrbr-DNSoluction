# %% [markdown]
# <a href="https://colab.research.google.com/github/Danielpvbrbr/-Danielpvbrbr-DNSoluction/blob/main/runOllama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update
# !apt-get install -y zstd
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,644 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,010 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.2 MB]
# ...

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
import subprocess
import os

# Start Ollama service in the background
# The output and errors will be redirected to nohup.out
# Using shell=True to interpret the nohup and &> redirection
subprocess.Popen("nohup ollama serve &> nohup.out &", shell=True)
# Out:
# <Popen: returncode: None args: 'nohup ollama serve &> nohup.out &'>

# %%
# !ollama pull mannix/llama3.1-8b-abliterated

# %%
# Read the contents of nohup.out to check the download status
with open('nohup.out', 'r') as f:
    print(f.read())

# %%
# !ollama run mannix/llama3.1-8b-abliterated "crie uma conexão em Go com banco PostgreSQL"
# Out:
# Para criar uma conexão com um banco PostgreSQL utilizando Go, você pode uti
# utilizar o pacote `github.com/lib/pq`. Primeiramente, instale o pacote:
#
# ```
# go get -u github.com/lib/pq
# ```
#
# Em seguida, crie o arquivo que contém a conexão e utilize o exemplo abaixo
# para criar uma conexão com o banco PostgreSQL:
# ```go
# package main
#
# import (
# 	"database/sql"
# 	"fmt"
#
# 	_ "github.com/lib/pq"
# )
#
# func main() {
# 	dsn := "user=seu_usuario password=sua_senha host=localhost port=5432 dbname
# dbname=seu_banco sslmode=disable"
# 	db, err := sql.Open("postgres", dsn)
# 	if err != nil {
# 		fmt.Println(err.Error())
# 		return
# 	}
# 	defer db.Close()
#
# 	err = db.Ping()
# 	if err != nil {
# 		fmt.Println(err.Error())
# 		return
# 	}
#
# 	fmt.Println("Conexão estabelecida com sucesso!")
# }
# ```
#
# Substitua `seu_usuario`, `sua_senha`, `localhost`, `5432` e `seu_banco` com
# com os valores reais da sua conexão.
#
# ...

# %%
# !pip install pyngrok

# %%
# !pkill ollama

# %%
# !OLLAMA_HOST=0.0.0.0:11434 ollama serve > ollama.log 2>&1 &

# %%
# !curl http://127.0.0.1:11434/api/tags
# Out:
# {"models":[{"name":"qwen2.5-coder:7b","model":"qwen2.5-coder:7b","modified_at":"2026-05-18T19:34:37.485358287Z","size":4683087561,"digest":"dae161e27b0e90dd1856c8bb3209201fd6736d8eb66298e75ed87571486f4364","details":{"parent_model":"","format":"gguf","family":"qwen2","families":["qwen2"],"parameter_size":"7.6B","quantization_level":"Q4_K_M"}},{"name":"llama3:latest","model":"llama3:latest","modified_at":"2026-05-18T19:33:42.1568488Z","size":4661224676,"digest":"365c0bd3c000a25d28ddbf732fe1c6add414de7275464c4e4d1c3b5fcb5d8ad1","details":{"parent_model":"","format":"gguf","family":"llama","families":["llama"],"parameter_size":"8.0B","quantization_level":"Q4_0"}}]}

# %%
from pyngrok import ngrok

ngrok.kill()
url = ngrok.connect(11434)
print(url)
# Out:
# NgrokTunnel: "https://3f19-34-186-30-192.ngrok-free.app" -> "http://localhost:11434"
